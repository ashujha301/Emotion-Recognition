# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("A:\Insurance1.csv")
df
# Out:
#     age  have_insurance
# 0    22               0
# 1    25               0
# 2    47               1
# 3    52               0
# 4    46               1
# 5    56               1
# 6    55               0
# 7    60               1
# 8    62               1
# 9    61               1
# 10   28               0
# 11   27               0
# 12   29               0
# 13   18               0

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.have_insurance,train_size=0.9)

# %%
x_test
# Out:
#     age
# 5    56
# 10   28

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0], dtype=int64)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.24791535, 0.75208465],
#        [0.94608771, 0.05391229]])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict([[70]])
# Out:
# array([1], dtype=int64)

# %%
import cv2 
import time
from fer import FER

# %%
img=plt.imread('Documents/happy.jpg')

# %%
plt.imshow(img)

# %%
detector=FER(mtcnn=True)

# %%
print(detector.detect_emotions(img))
# Out:
# [{'box': (893, 140, 291, 291), 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 1.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]

# %%
emotion,score=detector.top_emotion(img)

# %%
print(emotion,score)
# Out:
# happy 1.0
